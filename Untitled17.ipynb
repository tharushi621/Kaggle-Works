# %% [markdown]
# <a href="https://colab.research.google.com/github/tharushi621/Kaggle-Works/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('Salary_Data.csv')
df.head()
# Out:
#     Age  Gender Education Level          Job Title  Years of Experience  \
# 0  32.0    Male      Bachelor's  Software Engineer                  5.0
# 1  28.0  Female        Master's       Data Analyst                  3.0
# 2  45.0    Male             PhD     Senior Manager                 15.0
# 3  36.0  Female      Bachelor's    Sales Associate                  7.0
# 4  52.0    Male        Master's           Director                 20.0
#
#      Salary
# 0   90000.0
# 1   65000.0
# 2  150000.0
# 3   60000.0
# 4  200000.0

# %%
plt.figure(figsize=(8,6))
plt.scatter(df['Years of Experience'],df['Salary'],color='blue')
plt.title('Salary VS Years of Experience')
plt.ylabel('Salary')
plt.xlabel('Years of Experience')
plt.grid(True)
plt.show()

# %%
x=df[['Years of Experience']]
y=df['Salary']

# %%
x_train.isna().sum()
# Out:
# Years of Experience    3
# dtype: int64

# %%
median_val = x_train['Years of Experience'].median()

x_train['Years of Experience'] = x_train['Years of Experience'].fillna(median_val)

# %%
y_train.isna().sum()
# Out:
# np.int64(5)

# %%
mask = y_train.notna()

x_train = x_train[mask]
y_train = y_train[mask]

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2)

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()
